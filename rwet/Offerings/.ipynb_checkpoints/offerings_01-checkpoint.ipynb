# %% [markdown]
# # Altar.py
#
# This is an evolving prompt generator that asks me question about identity, ancestry, and community. Once it takes the text in, it returns to me a word salad of randomized choice words from the input (combined with the intro message) to create something that hopefully I can sift meaning from.

# %%
import time, sys, random, json, textwrap
import utils

f = open('source.json')
raw_data = json.load(f)
questions = raw_data['questions']
starters = raw_data['starters']

responses = []

intro_message = """Welcome to the altar.
    You are your ancestors, your descendants.
    You shape not moving forward or backwards but in all directions. 
    When you make an offering to this altar, you offer yourself a moment of reflection. 
    Press enter when you are ready. 
    """

generation_message = """ Thank you for offering those thoughts. 
Sift what you will from what has been given. 
"""

# Include the intro message in the word bank. 
responses.append(intro_message)

built_questions = []

chosen_questions = random.sample(questions, 3)
chosen_starters = random.sample(starters, 3)



#* ----Main Body of the Program--------------------------------------------------- */

utils.print_slow(intro_message)
input()
utils.print_slow("Please, share a few things.\n")
utils.print_slow(chosen_starters[0] + chosen_questions[0] + '\n')
print("----------------------")
responses.append(input())
print("----------------------")
utils.print_slow("Thank you. \n")
utils.print_slow(chosen_starters[1] + chosen_questions[1] + '\n')
print("----------------------")
responses.append(input())
print("----------------------")
utils.print_slow("Thank you. \n")
utils.print_slow(chosen_starters[2] + chosen_questions[2] + '\n')
print("----------------------")
responses.append(input())
print("----------------------")
time.sleep(1.2)
utils.print_slow(generation_message)

print("*****----------------------*****")
print("*****----------------------*****")

utils.generation_loop(responses)
# Out:
# Welcome to the altar.
#     You are your ancestors, your descendants.
#     You shape not moving forward or backwards but in all directions.
#     When you make an offering to this altar, you offer yourself a moment of reflection.
#     Press enter when you are ready.
#
# Please, share a few things.
# What is something you give your ancestors.
# ----------------------
# I give my ancestors a body through which their lineage is carried.
# ----------------------
# Thank you.
# Describe something you give your community.
# ----------------------
# I give my community an extra person to go on a coffee run with. I give them laughter and critique.
# ----------------------
# Thank you.
# Tell me about something your ancestors give you.
# ----------------------
# My ancestors give me a framework to grow into.
# ----------------------
#  Thank you for offering those thoughts.
# Sift what you will from what has been given.
# *****----------------------*****
# *****----------------------*****
# reflection. all altar, is you run and
# the moment ancestors which You extra
# carried. laughter You a with. when on
# shape ready. an framework go but
# ancestors, you in their me you I of
# enter into. offering give my your give
# person are coffee through an altar. body
# them offer grow I a My critique.
# ancestors forward moving are a Press to
# yourself or give to I to community my
# When backwards this directions. a
# lineage Welcome give make not
# *****----------------------*****
# *****----------------------*****
#
#
# Resift? y/n
# n
# Goodbye.
